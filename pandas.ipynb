# %% [markdown]
# # 10 Minutes to pandas
# ## Please learn pandas from these links.
# https://pandas.pydata.org/pandas-docs/stable/10min.html
#
# http://manishamde.github.io/blog/2013/03/07/pandas-and-python-top-10/#numpy
#
# ### You should be able to understand these commands:
# 1. Create and read data: Series and Data Frame, read_csv
# 2. View data: head, tail, index, values, describe
# 3. Select data: slicing, loc, iloc
# 4. Missing data: dropna, fillna, isna
# 5. apply and lambda
# 6. concat, append, reshape
# 6. SQL style function: merge, join, group by

# %% [markdown]
# # Question: please implement the code from these three pages.
# ## Page 1:
# http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/
# ## Page 2:
# http://www.gregreda.com/2013/10/26/working-with-pandas-dataframes/
# ## Page 3:
# http://www.gregreda.com/2013/10/26/using-pandas-on-the-movielens-dataset/
#
# # Make sure you understand all these commands and try to use them in your project.

# %%
import numpy as np
import pandas as pd

s = pd.Series([89, 'Word', (3.14,0), -110578, 'Test'],
              index=['X', 'Pi', 'D', 'B', 'L'])
print s

s['Pi']='new'

print s[type(s)==float]
# Your code goes here:

testData = {'Numbers': [1, 1, 202, 211, 2, 210, 211, 12],
        'Numbers and letters': ['adf', '234s', 'afs', '234rs', 'd345', 'L34rds', '54trdfs', '34s'],
        'chars': ['xcd', 'a','aaa', 'erd','aewd', 'aefd', 'dfg', 'gf'],
        'bool': [True, False, True, False, False, False, False, True]}
test = pd.DataFrame(testData, columns=['Numbers','Numbers and letters', 'chars', 'bool'])
test

df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data', header = None,
              names = ['letter', 'xbox', 'ybox', 'boxwidth', 'boxheight', 'onpix', 'xbar', 'ybar', 'x2bar', 'y2bar', 'xybar', 'x2ybr', 'xy2br', 'xedge', 'xegvy', 'yedge', 'yegvx'])

df.info()
df.dtypes
df.describe()

print df.head(3)


left = pd.DataFrame({'key': range(5), 
                           'left_value': ['1', '2', '3', '4', '5']})
right = pd.DataFrame({'key': range(2, 7), 
                           'right_value': ['6', '7', '8', '9', '10']})

print left
print right


inner = pd.merge(left, right, on='key', how='inner')
print 'inner\n',inner

right=pd.merge(left, right, on='key', how='right')
print'right',right

outer= pd.merge(left, right, on='key', how='outer')
print'outer',outer

con = pd.concat([left, right])
print 'con',con
# Out:
# X            89
# Pi         Word
# D     (3.14, 0)
# B       -110578
# L          Test
# dtype: object
# 89
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
# letter       20000 non-null object
# xbox         20000 non-null int64
# ybox         20000 non-null int64
# boxwidth     20000 non-null int64
# boxheight    20000 non-null int64
# onpix        20000 non-null int64
# xbar         20000 non-null int64
# ybar         20000 non-null int64
# x2bar        20000 non-null int64
# y2bar        20000 non-null int64
# xybar        20000 non-null int64
# x2ybr        20000 non-null int64
# xy2br        20000 non-null int64
# xedge        20000 non-null int64
# xegvy        20000 non-null int64
# yedge        20000 non-null int64
# yegvx        20000 non-null int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB
#   letter  xbox  ybox  boxwidth  boxheight  onpix  xbar  ybar  x2bar  y2bar  \
# ...
